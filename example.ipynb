# %%
## trainning 


# !python train_newdata.py --dataset '../ph2/' --arch UCM_Net --name ph2_nb_testing_batch_8 --img_ext .bmp --mask_ext _lesion.bmp  --epochs 300 --loss GT_BceDiceLoss_new1 --batch_size 8
# Out:
# /home/ubuntu/.local/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# --------------------
# name: ph2_nb_testing_batch_8
# epochs: 300
# batch_size: 8
# arch: UCM_Net
# deep_supervision: False
# input_channels: 3
# num_classes: 1
# input_w: 256
# input_h: 256
# loss: GT_BceDiceLoss_new1
# dataset: ../ph2/
# img_ext: .bmp
# mask_ext: _lesion.bmp
# optimizer: AdamW
# lr: 0.001
# momentum: 0.9
# weight_decay: 0.01
# nesterov: False
# nrand: 44
# scheduler: CosineAnnealingLR
# min_lr: 1e-05
# factor: 0.1
# patience: 2
# milestones: 1,2
# gamma: 0.6666666666666666
# early_stopping: -1
# cfg: None
# opts: None
# num_workers: 4
# zip: False
# cache_mode: part
# resume: None
# accumulation_steps: None
# use_checkpoint: False
# amp_opt_level: O1
# tag: None
# eval: False
# throughput: False
# --------------------
# UCM_Net(
#   (encoder1): Conv2d(3, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (ebn1): GroupNorm(4, 8, eps=1e-05, affine=True)
#   (norm1): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#   (norm2): LayerNorm((24,), eps=1e-05, elementwise_affine=True)
#   (norm3): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#   (norm4): LayerNorm((48,), eps=1e-05, elementwise_affine=True)
#   (norm5): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   (dnorm2): LayerNorm((48,), eps=1e-05, elementwise_affine=True)
#   (dnorm3): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#   (dnorm4): LayerNorm((24,), eps=1e-05, elementwise_affine=True)
#   (dnorm5): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#   (dnorm6): LayerNorm((8,), eps=1e-05, elementwise_affine=True)
#   (block_0_1): ModuleList(
#     (0): UCMBlock(
#       (drop_path): Identity()
#       (norm2): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (fc1): Linear(in_features=16, out_features=16, bias=True)
#       (dwconv): DWConv(
#         (dwconv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16)
#       )
#       (dwconv1): DWConv(
#         (dwconv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16)
#       )
#       (act): GELU(approximate=none)
#       (act1): GELU(approximate=none)
#       (fc2): Linear(in_features=16, out_features=16, bias=True)
#       (drop): Dropout(p=0.0, inplace=False)
#     )
#   )
#   (block0): ModuleList(
#     (0): UCMBlock(
#       (drop_path): Identity()
#       (norm2): LayerNorm((24,), eps=1e-05, elementwise_affine=True)
#       (fc1): Linear(in_features=24, out_features=24, bias=True)
#       (dwconv): DWConv(
#         (dwconv): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#       )
#       (dwconv1): DWConv(
#         (dwconv): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#       )
#       (act): GELU(approximate=none)
#       (act1): GELU(approximate=none)
#       (fc2): Linear(in_features=24, out_features=24, bias=True)
#       (drop): Dropout(p=0.0, inplace=False)
#     )
#   )
#   (block1): ModuleList(
#     (0): UCMBlock(
#       (drop_path): Identity()
#       (norm2): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (dwconv): DWConv(
#         (dwconv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#       )
#       (dwconv1): DWConv(
#         (dwconv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#       )
#       (act): GELU(approximate=none)
#       (act1): GELU(approximate=none)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (drop): Dropout(p=0.0, inplace=False)
#     )
#   )
#   (block2): ModuleList(
#     (0): UCMBlock(
#       (drop_path): Identity()
#       (norm2): LayerNorm((48,), eps=1e-05, elementwise_affine=True)
#       (fc1): Linear(in_features=48, out_features=48, bias=True)
#       (dwconv): DWConv(
#         (dwconv): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#       )
#       (dwconv1): DWConv(
#         (dwconv): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#       )
#       (act): GELU(approximate=none)
#       (act1): GELU(approximate=none)
#       (fc2): Linear(in_features=48, out_features=48, bias=True)
#       (drop): Dropout(p=0.0, inplace=False)
#     )
#   )
#   (block3): ModuleList(
#     (0): UCMBlock(
#       (drop_path): Identity()
#       (norm2): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       (fc1): Linear(in_features=64, out_features=64, bias=True)
#       (dwconv): DWConv(
#         (dwconv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#       )
#       (dwconv1): DWConv(
#         (dwconv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#       )
#       (act): GELU(approximate=none)
#       (act1): GELU(approximate=none)
#       (fc2): Linear(in_features=64, out_features=64, bias=True)
#       (drop): Dropout(p=0.0, inplace=False)
#     )
#   )
#   (dblock0): ModuleList(
#     (0): UCMBlock(
#       (drop_path): Identity()
#       (norm2): LayerNorm((48,), eps=1e-05, elementwise_affine=True)
#       (fc1): Linear(in_features=48, out_features=48, bias=True)
#       (dwconv): DWConv(
#         (dwconv): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#       )
#       (dwconv1): DWConv(
#         (dwconv): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#       )
#       (act): GELU(approximate=none)
#       (act1): GELU(approximate=none)
#       (fc2): Linear(in_features=48, out_features=48, bias=True)
#       (drop): Dropout(p=0.0, inplace=False)
#     )
#   )
#   (dblock1): ModuleList(
#     (0): UCMBlock(
#       (drop_path): Identity()
#       (norm2): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       (fc1): Linear(in_features=32, out_features=32, bias=True)
#       (dwconv): DWConv(
#         (dwconv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#       )
#       (dwconv1): DWConv(
#         (dwconv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#       )
#       (act): GELU(approximate=none)
#       (act1): GELU(approximate=none)
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (drop): Dropout(p=0.0, inplace=False)
#     )
#   )
#   (dblock2): ModuleList(
#     (0): UCMBlock(
#       (drop_path): Identity()
#       (norm2): LayerNorm((24,), eps=1e-05, elementwise_affine=True)
#       (fc1): Linear(in_features=24, out_features=24, bias=True)
#       (dwconv): DWConv(
#         (dwconv): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#       )
#       (dwconv1): DWConv(
#         (dwconv): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#       )
#       (act): GELU(approximate=none)
#       (act1): GELU(approximate=none)
#       (fc2): Linear(in_features=24, out_features=24, bias=True)
#       (drop): Dropout(p=0.0, inplace=False)
#     )
#   )
#   (dblock3): ModuleList(
#     (0): UCMBlock(
#       (drop_path): Identity()
#       (norm2): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (fc1): Linear(in_features=16, out_features=16, bias=True)
#       (dwconv): DWConv(
#         (dwconv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16)
#       )
#       (dwconv1): DWConv(
#         (dwconv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16)
#       )
#       (act): GELU(approximate=none)
#       (act1): GELU(approximate=none)
#       (fc2): Linear(in_features=16, out_features=16, bias=True)
#       (drop): Dropout(p=0.0, inplace=False)
#     )
#   )
#   (dblock4): ModuleList(
#     (0): UCMBlock(
#       (drop_path): Identity()
#       (norm2): LayerNorm((8,), eps=1e-05, elementwise_affine=True)
#       (fc1): Linear(in_features=8, out_features=8, bias=True)
#       (dwconv): DWConv(
#         (dwconv): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8)
#       )
#       (dwconv1): DWConv(
#         (dwconv): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8)
#       )
#       (act): GELU(approximate=none)
#       (act1): GELU(approximate=none)
#       (fc2): Linear(in_features=8, out_features=8, bias=True)
#       (drop): Dropout(p=0.0, inplace=False)
#     )
#   )
#   (patch_embed1): OverlapPatchEmbed(
#     (proj): Conv2d(8, 16, kernel_size=(1, 1), stride=(2, 2))
#     (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#   )
#   (patch_embed2): OverlapPatchEmbed(
#     (proj): Conv2d(16, 24, kernel_size=(1, 1), stride=(2, 2))
#     (norm): LayerNorm((24,), eps=1e-05, elementwise_affine=True)
#   )
#   (patch_embed3): OverlapPatchEmbed(
#     (proj): Conv2d(24, 32, kernel_size=(1, 1), stride=(2, 2))
#     (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#   )
#   (patch_embed4): OverlapPatchEmbed(
#     (proj): Conv2d(32, 48, kernel_size=(1, 1), stride=(2, 2))
#     (norm): LayerNorm((48,), eps=1e-05, elementwise_affine=True)
#   )
#   (patch_embed5): OverlapPatchEmbed(
#     (proj): Conv2d(48, 64, kernel_size=(1, 1), stride=(2, 2))
#     (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   )
#   (decoder0): Conv2d(64, 48, kernel_size=(1, 1), stride=(1, 1))
#   (decoder1): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1))
#   (decoder2): Conv2d(32, 24, kernel_size=(1, 1), stride=(1, 1))
#   (decoder3): Conv2d(24, 16, kernel_size=(1, 1), stride=(1, 1))
#   (decoder4): Conv2d(16, 8, kernel_size=(1, 1), stride=(1, 1))
#   (decoder5): Conv2d(8, 3, kernel_size=(1, 1), stride=(1, 1))
#   (dbn0): GroupNorm(4, 48, eps=1e-05, affine=True)
#   (dbn1): GroupNorm(4, 32, eps=1e-05, affine=True)
#   (dbn2): GroupNorm(4, 24, eps=1e-05, affine=True)
#   (dbn3): GroupNorm(4, 16, eps=1e-05, affine=True)
#   (dbn4): GroupNorm(4, 8, eps=1e-05, affine=True)
#   (finalpre0): Conv2d(48, 1, kernel_size=(1, 1), stride=(1, 1))
#   (finalpre1): Conv2d(32, 1, kernel_size=(1, 1), stride=(1, 1))
#   (finalpre2): Conv2d(24, 1, kernel_size=(1, 1), stride=(1, 1))
#   (finalpre3): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1))
#   (finalpre4): Conv2d(8, 1, kernel_size=(1, 1), stride=(1, 1))
#   (final): Conv2d(3, 1, kernel_size=(1, 1), stride=(1, 1))
# )
# Total Parameters: 47436
# Trainable Parameters: 47436
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv2d'>.
# [INFO] Register count_normalization() for <class 'torch.nn.modules.normalization.LayerNorm'>.
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.dropout.Dropout'>.
# GigaFLOPs: 0.045193216
# train_img_ids 140
# val_img_ids 60
# Epoch [0/300]
# 100%|███████████████████████| 18/18 [00:02<00:00,  7.46it/s, loss=4.9, iou=0.42]
#  98%|████████▊| 59/60 [00:00<00:00, 81.33it/s, loss=4.48, iou=0.504, dice=0.649]miou 0.5284371399422385
# f1_or_dsc 0.6914738279157607
# 100%|█████████| 60/60 [00:03<00:00, 19.01it/s, loss=4.48, iou=0.504, dice=0.649]
# loss 4.8969 - iou 0.4198 - val_loss 4.4774 - val_iou 0.5038
# => saved best model
# best_iou 0.5037715330252838
# best_dice 0.6488729036990252
# Epoch [1/300]
# 100%|█████████████████████| 18/18 [00:01<00:00,  9.13it/s, loss=4.31, iou=0.553]
#  98%|████████▊| 59/60 [00:00<00:00, 82.55it/s, loss=4.06, iou=0.554, dice=0.694]miou 0.5765137600236582
# f1_or_dsc 0.7313780249085889
# 100%|█████████| 60/60 [00:03<00:00, 19.49it/s, loss=4.06, iou=0.554, dice=0.694]
# loss 4.3140 - iou 0.5532 - val_loss 4.0612 - val_iou 0.5543
# => saved best model
# best_iou 0.5542799599562888
# best_dice 0.6940648102243673
# Epoch [2/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.84it/s, loss=4.01, iou=0.589]
#  98%|████████▊| 59/60 [00:00<00:00, 80.65it/s, loss=3.77, iou=0.624, dice=0.752]miou 0.6370546538051586
# f1_or_dsc 0.7782936902251774
# 100%|█████████| 60/60 [00:03<00:00, 19.00it/s, loss=3.77, iou=0.624, dice=0.752]
# loss 4.0141 - iou 0.5895 - val_loss 3.7747 - val_iou 0.6243
# => saved best model
# best_iou 0.6242780845937729
# best_dice 0.751895380661066
# Epoch [3/300]
# 100%|█████████████████████| 18/18 [00:01<00:00,  9.03it/s, loss=3.77, iou=0.634]
#  98%|████████▊| 59/60 [00:00<00:00, 82.10it/s, loss=3.52, iou=0.727, dice=0.831]miou 0.7173097132562678
# f1_or_dsc 0.8353877087157968
# 100%|█████████| 60/60 [00:03<00:00, 19.22it/s, loss=3.52, iou=0.727, dice=0.831]
# loss 3.7663 - iou 0.6342 - val_loss 3.5201 - val_iou 0.7270
# => saved best model
# best_iou 0.7270059172154093
# best_dice 0.8308058827946555
# Epoch [4/300]
# 100%|██████████████████████| 18/18 [00:01<00:00,  9.07it/s, loss=3.55, iou=0.69]
#  98%|████████▊| 59/60 [00:00<00:00, 80.97it/s, loss=3.27, iou=0.757, dice=0.853]miou 0.7528593866673533
# f1_or_dsc 0.85900716554194
# 100%|█████████| 60/60 [00:03<00:00, 19.35it/s, loss=3.27, iou=0.757, dice=0.853]
# loss 3.5545 - iou 0.6904 - val_loss 3.2700 - val_iou 0.7574
# => saved best model
# best_iou 0.7574316171089993
# best_dice 0.8528142711081793
# Epoch [5/300]
# 100%|█████████████████████| 18/18 [00:01<00:00,  9.05it/s, loss=3.32, iou=0.724]
#  98%|████████▊| 59/60 [00:00<00:00, 81.18it/s, loss=3.14, iou=0.744, dice=0.842]miou 0.7605169956080002
# f1_or_dsc 0.8639700695935096
# 100%|█████████| 60/60 [00:03<00:00, 19.37it/s, loss=3.14, iou=0.744, dice=0.842]
# loss 3.3170 - iou 0.7242 - val_loss 3.1365 - val_iou 0.7440
# best_iou 0.7574316171089993
# best_dice 0.8528142711081793
# Epoch [6/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.98it/s, loss=3.14, iou=0.753]
#  98%|███████████▊| 59/60 [00:00<00:00, 76.83it/s, loss=3, iou=0.761, dice=0.852]miou 0.7651626311167354
# f1_or_dsc 0.8669599249703729
# 100%|████████████| 60/60 [00:03<00:00, 19.04it/s, loss=3, iou=0.761, dice=0.852]
# loss 3.1359 - iou 0.7526 - val_loss 2.9966 - val_iou 0.7613
# => saved best model
# best_iou 0.7612929572653699
# best_dice 0.8521281517552918
# Epoch [7/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.76it/s, loss=2.94, iou=0.783]
#  98%|████████▊| 59/60 [00:00<00:00, 78.98it/s, loss=2.68, iou=0.829, dice=0.902]miou 0.8323073933450925
# f1_or_dsc 0.9084800905874396
# 100%|█████████| 60/60 [00:03<00:00, 19.16it/s, loss=2.68, iou=0.829, dice=0.902]
# loss 2.9433 - iou 0.7828 - val_loss 2.6807 - val_iou 0.8287
# => saved best model
# best_iou 0.8286623384113165
# best_dice 0.9019452529175225
# Epoch [8/300]
# 100%|█████████████████████| 18/18 [00:01<00:00,  9.25it/s, loss=2.73, iou=0.814]
#  98%|█████████▊| 59/60 [00:00<00:00, 82.62it/s, loss=2.6, iou=0.799, dice=0.879]miou 0.8323073933450925
# f1_or_dsc 0.9084800905874396
# 100%|██████████| 60/60 [00:03<00:00, 19.22it/s, loss=2.6, iou=0.799, dice=0.879]
# loss 2.7333 - iou 0.8141 - val_loss 2.5963 - val_iou 0.7986
# best_iou 0.8286623384113165
# best_dice 0.9019452529175225
# Epoch [9/300]
# 100%|███████████████████████| 18/18 [00:01<00:00,  9.08it/s, loss=2.6, iou=0.82]
#  98%|████████▊| 59/60 [00:00<00:00, 81.88it/s, loss=2.63, iou=0.752, dice=0.845]miou 0.8323073933450925
# f1_or_dsc 0.9084800905874396
# 100%|█████████| 60/60 [00:03<00:00, 19.45it/s, loss=2.63, iou=0.752, dice=0.845]
# loss 2.5963 - iou 0.8196 - val_loss 2.6341 - val_iou 0.7518
# best_iou 0.8286623384113165
# best_dice 0.9019452529175225
# Epoch [10/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.88it/s, loss=2.53, iou=0.819]
#  98%|████████▊| 59/60 [00:00<00:00, 83.17it/s, loss=2.34, iou=0.837, dice=0.907]miou 0.8391436989908998
# f1_or_dsc 0.9125373938440163
# 100%|█████████| 60/60 [00:03<00:00, 19.16it/s, loss=2.34, iou=0.837, dice=0.907]
# loss 2.5322 - iou 0.8195 - val_loss 2.3414 - val_iou 0.8372
# => saved best model
# best_iou 0.8372111330611435
# best_dice 0.9065554675914654
# Epoch [11/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.71it/s, loss=2.39, iou=0.832]
#  98%|██████████▊| 59/60 [00:01<00:00, 74.42it/s, loss=2.3, iou=0.813, dice=0.89]miou 0.8391436989908998
# f1_or_dsc 0.9125373938440163
# 100%|███████████| 60/60 [00:03<00:00, 18.68it/s, loss=2.3, iou=0.813, dice=0.89]
# loss 2.3929 - iou 0.8323 - val_loss 2.3042 - val_iou 0.8129
# best_iou 0.8372111330611435
# best_dice 0.9065554675914654
# Epoch [12/300]
# 100%|██████████████████████| 18/18 [00:02<00:00,  8.94it/s, loss=2.3, iou=0.853]
#  98%|█████████▊| 59/60 [00:00<00:00, 80.24it/s, loss=2.22, iou=0.83, dice=0.902]miou 0.8391436989908998
# f1_or_dsc 0.9125373938440163
# 100%|██████████| 60/60 [00:03<00:00, 19.55it/s, loss=2.22, iou=0.83, dice=0.902]
# loss 2.3018 - iou 0.8528 - val_loss 2.2161 - val_iou 0.8302
# best_iou 0.8372111330611435
# best_dice 0.9065554675914654
# Epoch [13/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.61it/s, loss=2.23, iou=0.849]
#  98%|████████▊| 59/60 [00:00<00:00, 82.97it/s, loss=2.14, iou=0.836, dice=0.906]miou 0.8428892893573117
# f1_or_dsc 0.9147476131366095
# 100%|█████████| 60/60 [00:03<00:00, 19.34it/s, loss=2.14, iou=0.836, dice=0.906]
# loss 2.2338 - iou 0.8487 - val_loss 2.1406 - val_iou 0.8362
# best_iou 0.8372111330611435
# best_dice 0.9065554675914654
# Epoch [14/300]
# 100%|█████████████████████| 18/18 [00:01<00:00,  9.19it/s, loss=2.16, iou=0.858]
#  98%|████████▊| 59/60 [00:00<00:00, 80.38it/s, loss=2.07, iou=0.844, dice=0.912]miou 0.8500443127116806
# f1_or_dsc 0.9189448132361091
# 100%|█████████| 60/60 [00:03<00:00, 19.11it/s, loss=2.07, iou=0.844, dice=0.912]
# loss 2.1630 - iou 0.8581 - val_loss 2.0657 - val_iou 0.8444
# => saved best model
# best_iou 0.8444483594257949
# best_dice 0.9121435042585797
# Epoch [15/300]
# 100%|█████████████████████| 18/18 [00:01<00:00,  9.16it/s, loss=2.12, iou=0.856]
#  98%|████████▊| 59/60 [00:00<00:00, 75.18it/s, loss=2.01, iou=0.852, dice=0.917]miou 0.859977016619041
# f1_or_dsc 0.9247178959041737
# 100%|█████████| 60/60 [00:03<00:00, 18.91it/s, loss=2.01, iou=0.852, dice=0.917]
# loss 2.1193 - iou 0.8563 - val_loss 2.0066 - val_iou 0.8518
# => saved best model
# best_iou 0.8518191196253443
# best_dice 0.9173188272140937
# Epoch [16/300]
# 100%|█████████████████████| 18/18 [00:01<00:00,  9.11it/s, loss=2.07, iou=0.866]
#  98%|████████▊| 59/60 [00:00<00:00, 82.00it/s, loss=2.15, iou=0.804, dice=0.882]miou 0.859977016619041
# f1_or_dsc 0.9247178959041737
# 100%|█████████| 60/60 [00:03<00:00, 19.39it/s, loss=2.15, iou=0.804, dice=0.882]
# loss 2.0729 - iou 0.8665 - val_loss 2.1540 - val_iou 0.8036
# best_iou 0.8518191196253443
# best_dice 0.9173188272140937
# Epoch [17/300]
# 100%|█████████████████████| 18/18 [00:01<00:00,  9.45it/s, loss=2.05, iou=0.857]
#  98%|████████▊| 59/60 [00:00<00:00, 78.40it/s, loss=1.92, iou=0.866, dice=0.926]miou 0.8709510868325443
# f1_or_dsc 0.9310249668867981
# 100%|█████████| 60/60 [00:03<00:00, 19.19it/s, loss=1.92, iou=0.866, dice=0.926]
# loss 2.0505 - iou 0.8572 - val_loss 1.9187 - val_iou 0.8663
# => saved best model
# best_iou 0.8663114756947438
# best_dice 0.9262601357240127
# Epoch [18/300]
# 100%|████████████████████████| 18/18 [00:02<00:00,  8.89it/s, loss=2, iou=0.871]
#  98%|████████▊| 59/60 [00:00<00:00, 76.91it/s, loss=1.91, iou=0.861, dice=0.923]miou 0.8709510868325443
# f1_or_dsc 0.9310249668867981
# 100%|█████████| 60/60 [00:03<00:00, 19.11it/s, loss=1.91, iou=0.861, dice=0.923]
# loss 1.9989 - iou 0.8708 - val_loss 1.9083 - val_iou 0.8609
# best_iou 0.8663114756947438
# best_dice 0.9262601357240127
# Epoch [19/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.58it/s, loss=1.95, iou=0.871]
#  98%|████████▊| 59/60 [00:00<00:00, 83.52it/s, loss=1.89, iou=0.859, dice=0.922]miou 0.8709510868325443
# f1_or_dsc 0.9310249668867981
# 100%|█████████| 60/60 [00:03<00:00, 19.52it/s, loss=1.89, iou=0.859, dice=0.922]
# loss 1.9542 - iou 0.8706 - val_loss 1.8947 - val_iou 0.8593
# best_iou 0.8663114756947438
# best_dice 0.9262601357240127
# Epoch [20/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.97it/s, loss=1.94, iou=0.871]
#  98%|████████▊| 59/60 [00:00<00:00, 78.57it/s, loss=1.87, iou=0.866, dice=0.926]miou 0.8709510868325443
# f1_or_dsc 0.9310249668867981
# 100%|█████████| 60/60 [00:03<00:00, 19.18it/s, loss=1.87, iou=0.866, dice=0.926]
# loss 1.9422 - iou 0.8713 - val_loss 1.8730 - val_iou 0.8656
# best_iou 0.8663114756947438
# best_dice 0.9262601357240127
# Epoch [21/300]
# 100%|█████████████████████| 18/18 [00:01<00:00,  9.16it/s, loss=1.88, iou=0.886]
#  98%|████████▊| 59/60 [00:00<00:00, 77.89it/s, loss=1.88, iou=0.858, dice=0.921]miou 0.8709510868325443
# f1_or_dsc 0.9310249668867981
# 100%|█████████| 60/60 [00:03<00:00, 19.11it/s, loss=1.88, iou=0.858, dice=0.921]
# loss 1.8827 - iou 0.8858 - val_loss 1.8824 - val_iou 0.8583
# best_iou 0.8663114756947438
# best_dice 0.9262601357240127
# Epoch [22/300]
# 100%|██████████████████████| 18/18 [00:02<00:00,  8.86it/s, loss=1.9, iou=0.871]
#  98%|████████▊| 59/60 [00:00<00:00, 82.90it/s, loss=1.82, iou=0.876, dice=0.933]miou 0.878423786235496
# f1_or_dsc 0.9352775371269377
# 100%|█████████| 60/60 [00:03<00:00, 19.12it/s, loss=1.82, iou=0.876, dice=0.933]
# loss 1.9016 - iou 0.8707 - val_loss 1.8233 - val_iou 0.8764
# => saved best model
# best_iou 0.8763683132621822
# best_dice 0.9328843458133491
# Epoch [23/300]
# 100%|█████████████████████| 18/18 [00:01<00:00,  9.11it/s, loss=1.89, iou=0.878]
#  98%|████████▊| 59/60 [00:00<00:00, 83.33it/s, loss=1.87, iou=0.858, dice=0.921]miou 0.878423786235496
# f1_or_dsc 0.9352775371269377
# 100%|█████████| 60/60 [00:03<00:00, 19.37it/s, loss=1.87, iou=0.858, dice=0.921]
# loss 1.8867 - iou 0.8775 - val_loss 1.8695 - val_iou 0.8576
# best_iou 0.8763683132621822
# best_dice 0.9328843458133491
# Epoch [24/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.86it/s, loss=1.89, iou=0.874]
#  98%|█████████▊| 59/60 [00:00<00:00, 75.66it/s, loss=1.83, iou=0.871, dice=0.93]miou 0.878423786235496
# f1_or_dsc 0.9352775371269377
# 100%|██████████| 60/60 [00:03<00:00, 18.75it/s, loss=1.83, iou=0.871, dice=0.93]
# loss 1.8939 - iou 0.8740 - val_loss 1.8296 - val_iou 0.8714
# best_iou 0.8763683132621822
# best_dice 0.9328843458133491
# Epoch [25/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.81it/s, loss=1.89, iou=0.874]
# 100%|█████████| 60/60 [00:00<00:00, 80.83it/s, loss=1.83, iou=0.867, dice=0.927]miou 0.878423786235496
# f1_or_dsc 0.9352775371269377
# 100%|█████████| 60/60 [00:03<00:00, 19.11it/s, loss=1.83, iou=0.867, dice=0.927]
# loss 1.8911 - iou 0.8743 - val_loss 1.8317 - val_iou 0.8674
# best_iou 0.8763683132621822
# best_dice 0.9328843458133491
# Epoch [26/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.86it/s, loss=1.85, iou=0.886]
#  98%|████████▊| 59/60 [00:00<00:00, 79.09it/s, loss=1.83, iou=0.868, dice=0.928]miou 0.878423786235496
# f1_or_dsc 0.9352775371269377
# 100%|█████████| 60/60 [00:03<00:00, 19.29it/s, loss=1.83, iou=0.868, dice=0.928]
# loss 1.8464 - iou 0.8864 - val_loss 1.8267 - val_iou 0.8685
# best_iou 0.8763683132621822
# best_dice 0.9328843458133491
# Epoch [27/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.80it/s, loss=1.85, iou=0.881]
#  98%|████████▊| 59/60 [00:00<00:00, 78.39it/s, loss=1.84, iou=0.866, dice=0.926]miou 0.878423786235496
# f1_or_dsc 0.9352775371269377
# 100%|█████████| 60/60 [00:03<00:00, 19.11it/s, loss=1.84, iou=0.866, dice=0.926]
# loss 1.8513 - iou 0.8813 - val_loss 1.8351 - val_iou 0.8657
# best_iou 0.8763683132621822
# best_dice 0.9328843458133491
# Epoch [28/300]
# 100%|█████████████████████| 18/18 [00:01<00:00,  9.13it/s, loss=1.87, iou=0.877]
#  98%|████████▊| 59/60 [00:00<00:00, 79.51it/s, loss=1.83, iou=0.868, dice=0.927]miou 0.878423786235496
# f1_or_dsc 0.9352775371269377
# 100%|█████████| 60/60 [00:03<00:00, 18.76it/s, loss=1.83, iou=0.868, dice=0.927]
# loss 1.8708 - iou 0.8774 - val_loss 1.8267 - val_iou 0.8677
# best_iou 0.8763683132621822
# best_dice 0.9328843458133491
# Epoch [29/300]
# 100%|██████████████████████| 18/18 [00:02<00:00,  8.91it/s, loss=1.84, iou=0.89]
#  98%|████████▊| 59/60 [00:00<00:00, 78.04it/s, loss=1.82, iou=0.869, dice=0.928]miou 0.878423786235496
# f1_or_dsc 0.9352775371269377
# 100%|█████████| 60/60 [00:03<00:00, 19.22it/s, loss=1.82, iou=0.869, dice=0.928]
# loss 1.8409 - iou 0.8896 - val_loss 1.8241 - val_iou 0.8686
# best_iou 0.8763683132621822
# best_dice 0.9328843458133491
# Epoch [30/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.88it/s, loss=1.84, iou=0.886]
#  98%|████████▊| 59/60 [00:00<00:00, 75.73it/s, loss=1.82, iou=0.869, dice=0.928]miou 0.878423786235496
# f1_or_dsc 0.9352775371269377
# 100%|█████████| 60/60 [00:03<00:00, 19.01it/s, loss=1.82, iou=0.869, dice=0.928]
# loss 1.8430 - iou 0.8856 - val_loss 1.8237 - val_iou 0.8685
# best_iou 0.8763683132621822
# best_dice 0.9328843458133491
# Epoch [31/300]
# 100%|█████████████████████| 18/18 [00:01<00:00,  9.10it/s, loss=1.85, iou=0.885]
#  98%|████████▊| 59/60 [00:01<00:00, 72.02it/s, loss=1.82, iou=0.869, dice=0.928]miou 0.878423786235496
# f1_or_dsc 0.9352775371269377
# 100%|█████████| 60/60 [00:03<00:00, 18.58it/s, loss=1.82, iou=0.869, dice=0.928]
# loss 1.8484 - iou 0.8853 - val_loss 1.8218 - val_iou 0.8690
# best_iou 0.8763683132621822
# best_dice 0.9328843458133491
# Epoch [32/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.99it/s, loss=1.84, iou=0.888]
#  98%|████████▊| 59/60 [00:00<00:00, 80.35it/s, loss=1.82, iou=0.869, dice=0.928]miou 0.878423786235496
# f1_or_dsc 0.9352775371269377
# 100%|█████████| 60/60 [00:03<00:00, 19
# best_iou 0.8763683132621822
# best_dice 0.9328843458133491
# Epoch [41/300]
# 100%|███████████████████████| 18/18 [00:02<00:00,  8.80it/s, loss=1.8, iou=0.88]
#  98%|████████▊| 59/60 [00:00<00:00, 80.40it/s, loss=1.73, iou=0.876, dice=0.933]miou 0.878423786235496
# f1_or_dsc 0.9352775371269377
# 100%|█████████| 60/60 [00:03<00:00, 19.36it/s, loss=1.73, iou=0.876, dice=0.933]
# loss 1.7951 - iou 0.8797 - val_loss 1.7281 - val_iou 0.8761
# best_iou 0.8763683132621822
# best_dice 0.9328843458133491
# Epoch [42/300]
# 100%|█████████████████████| 18/18 [00:01<00:00,  9.16it/s, loss=1.78, iou=0.883]
#  98%|█████████▊| 59/60 [00:00<00:00, 72.77it/s, loss=1.71, iou=0.88, dice=0.935]miou 0.8820798806291507
# f1_or_dsc 0.9373458477589004
# 100%|██████████| 60/60 [00:03<00:00, 18.68it/s, loss=1.71, iou=0.88, dice=0.935]
# loss 1.7787 - iou 0.8834 - val_loss 1.7071 - val_iou 0.8797
# => saved best model
# best_iou 0.8796719326297583
# best_dice 0.9349122029849773
# Epoch [43/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.98it/s, loss=1.75, iou=0.888]
#  98%|████████▊| 59/60 [00:00<00:00, 77.59it/s, loss=1.74, iou=0.869, dice=0.929]miou 0.8820798806291507
# f1_or_dsc 0.9373458477589004
# 100%|█████████| 60/60 [00:03<00:00, 19.20it/s, loss=1.74, iou=0.869, dice=0.929]
# loss 1.7465 - iou 0.8881 - val_loss 1.7399 - val_iou 0.8695
# best_iou 0.8796719326297583
# best_dice 0.9349122029849773
# Epoch [44/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.96it/s, loss=1.74, iou=0.886]
#  98%|████████▊| 59/60 [00:00<00:00, 78.66it/s, loss=1.67, iou=0.881, dice=0.936]miou 0.8855648477224207
# f1_or_dsc 0.9393098824387791
# 100%|█████████| 60/60 [00:03<00:00, 18.66it/s, loss=1.67, iou=0.881, dice=0.936]
# loss 1.7375 - iou 0.8860 - val_loss 1.6660 - val_iou 0.8814
# => saved best model
# best_iou 0.881358010410957
# best_dice 0.9359299219907856
# Epoch [45/300]
# 100%|█████████████████████| 18/18 [00:01<00:00,  9.05it/s, loss=1.75, iou=0.877]
#  98%|████████▊| 59/60 [00:00<00:00, 77.42it/s, loss=1.71, iou=0.867, dice=0.927]miou 0.8855648477224207
# f1_or_dsc 0.9393098824387791
# 100%|█████████| 60/60 [00:03<00:00, 18.97it/s, loss=1.71, iou=0.867, dice=0.927]
# loss 1.7539 - iou 0.8769 - val_loss 1.7070 - val_iou 0.8672
# best_iou 0.881358010410957
# best_dice 0.9359299219907856
# Epoch [46/300]
# 100%|█████████████████████| 18/18 [00:01<00:00,  9.08it/s, loss=1.79, iou=0.869]
#  98%|█████████▊| 59/60 [00:00<00:00, 74.23it/s, loss=1.7, iou=0.853, dice=0.918]miou 0.8855648477224207
# f1_or_dsc 0.9393098824387791
# 100%|██████████| 60/60 [00:03<00:00, 18.77it/s, loss=1.7, iou=0.853, dice=0.918]
# loss 1.7863 - iou 0.8692 - val_loss 1.7016 - val_iou 0.8532
# best_iou 0.881358010410957
# best_dice 0.9359299219907856
# Epoch [47/300]
# 100%|█████████████████████| 18/18 [00:01<00:00,  9.13it/s, loss=1.74, iou=0.877]
#  98%|████████▊| 59/60 [00:00<00:00, 81.53it/s, loss=1.75, iou=0.838, dice=0.909]miou 0.8855648477224207
# f1_or_dsc 0.9393098824387791
# 100%|█████████| 60/60 [00:03<00:00, 19.38it/s, loss=1.75, iou=0.838, dice=0.909]
# loss 1.7389 - iou 0.8768 - val_loss 1.7454 - val_iou 0.8380
# best_iou 0.881358010410957
# best_dice 0.9359299219907856
# Epoch [48/300]
# 100%|█████████████████████| 18/18 [00:01<00:00,  9.02it/s, loss=1.73, iou=0.863]
#  98%|████████▊| 59/60 [00:00<00:00, 82.63it/s, loss=1.66, iou=0.857, dice=0.921]miou 0.8855648477224207
# f1_or_dsc 0.9393098824387791
# 100%|█████████| 60/60 [00:03<00:00, 19.79it/s, loss=1.66, iou=0.857, dice=0.921]
# loss 1.7293 - iou 0.8630 - val_loss 1.6589 - val_iou 0.8571
# best_iou 0.881358010410957
# best_dice 0.9359299219907856
# Epoch [49/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.95it/s, loss=1.65, iou=0.883]
#  98%|████████▊| 59/60 [00:00<00:00, 79.36it/s, loss=1.65, iou=0.863, dice=0.924]miou 0.8855648477224207
# f1_or_dsc 0.9393098824387791
# 100%|█████████| 60/60 [00:03<00:00, 19.23it/s, loss=1.65, iou=0.863, dice=0.924]
# loss 1.6473 - iou 0.8829 - val_loss 1.6488 - val_iou 0.8628
# best_iou 0.881358010410957
# best_dice 0.9359299219907856
# Epoch [50/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.84it/s, loss=1.67, iou=0.876]
#  98%|████████▊| 59/60 [00:00<00:00, 77.79it/s, loss=1.65, iou=0.849, dice=0.916]miou 0.8855648477224207
# f1_or_dsc 0.9393098824387791
# 100%|█████████| 60/60 [00:03<00:00, 19.12it/s, loss=1.65, iou=0.849, dice=0.916]
# loss 1.6747 - iou 0.8762 - val_loss 1.6506 - val_iou 0.8493
# best_iou 0.881358010410957
# best_dice 0.9359299219907856
# Epoch [51/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.63it/s, loss=1.64, iou=0.872]
#  98%|████████▊| 59/60 [00:00<00:00, 80.82it/s, loss=1.56, iou=0.876, dice=0.932]miou 0.8855648477224207
# f1_or_dsc 0.9393098824387791
# 100%|█████████| 60/60 [00:03<00:00, 19.28it/s, loss=1.56, iou=0.876, dice=0.932]
# loss 1.6414 - iou 0.8724 - val_loss 1.5601 - val_iou 0.8758
# best_iou 0.881358010410957
# best_dice 0.9359299219907856
# Epoch [52/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.87it/s, loss=1.62, iou=0.883]
#  98%|████████▊| 59/60 [00:00<00:00, 72.97it/s, loss=1.64, iou=0.837, dice=0.908]miou 0.8855648477224207
# f1_or_dsc 0.9393098824387791
# 100%|█████████| 60/60 [00:03<00:00, 18.81it/s, loss=1.64, iou=0.837, dice=0.908]
# loss 1.6184 - iou 0.8834 - val_loss 1.6444 - val_iou 0.8372
# best_iou 0.881358010410957
# best_dice 0.9359299219907856
# Epoch [53/300]
# 100%|█████████████████████| 18/18 [00:01<00:00,  9.30it/s, loss=1.66, iou=0.869]
#  98%|█████████▊| 59/60 [00:00<00:00, 78.47it/s, loss=1.56, iou=0.87, dice=0.929]miou 0.8855648477224207
# f1_or_dsc 0.9393098824387791
# 100%|██████████| 60/60 [00:03<00:00, 19.26it/s, loss=1.56, iou=0.87, dice=0.929]
# loss 1.6642 - iou 0.8692 - val_loss 1.5597 - val_iou 0.8700
# best_iou 0.881358010410957
# best_dice 0.9359299219907856
# Epoch [54/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.82it/s, loss=1.59, iou=0.878]
#  98%|██████████▊| 59/60 [00:00<00:00, 79.20it/s, loss=1.5, iou=0.88, dice=0.935]miou 0.8868855503051494
# f1_or_dsc 0.9400522995808847
# 100%|███████████| 60/60 [00:03<00:00, 19.00it/s, loss=1.5, iou=0.88, dice=0.935]
# loss 1.5923 - iou 0.8783 - val_loss 1.4966 - val_iou 0.8804
# best_iou 0.881358010410957
# best_dice 0.9359299219907856
# Epoch [55/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.92it/s, loss=1.59, iou=0.872]
#  98%|████████▊| 59/60 [00:00<00:00, 78.37it/s, loss=1.48, iou=0.881, dice=0.935]miou 0.8868855503051494
# f1_or_dsc 0.9400522995808847
# 100%|█████████| 60/60 [00:03<00:00, 18.87it/s, loss=1.48, iou=0.881, dice=0.935]
# loss 1.5888 - iou 0.8716 - val_loss 1.4813 - val_iou 0.8807
# best_iou 0.881358010410957
# best_dice 0.9359299219907856
# Epoch [56/300]
# 100%|██████████████████████| 18/18 [00:02<00:00,  8.82it/s, loss=1.53, iou=0.88]
#  98%|████████▊| 59/60 [00:00<00:00, 80.62it/s, loss=1.47, iou=0.877, dice=0.933]miou 0.8868855503051494
# f1_or_dsc 0.9400522995808847
# 100%|█████████| 60/60 [00:03<00:00, 19.43it/s, loss=1.47, iou=0.877, dice=0.933]
# loss 1.5317 - iou 0.8799 - val_loss 1.4709 - val_iou 0.8768
# best_iou 0.881358010410957
# best_dice 0.9359299219907856
# Epoch [57/300]
# 100%|██████████████████████| 18/18 [00:02<00:00,  8.61it/s, loss=1.5, iou=0.883]
#  98%|████████▊| 59/60 [00:00<00:00, 76.60it/s, loss=1.45, iou=0.879, dice=0.934]miou 0.8868855503051494
# f1_or_dsc 0.9400522995808847
# 100%|█████████| 60/60 [00:03<00:00, 19.17it/s, loss=1.45, iou=0.879, dice=0.934]
# loss 1.5035 - iou 0.8833 - val_loss 1.4518 - val_iou 0.8786
# best_iou 0.881358010410957
# best_dice 0.9359299219907856
# Epoch [58/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.58it/s, loss=1.53, iou=0.876]
#  98%|████████▊| 59/60 [00:00<00:00, 76.21it/s, loss=1.57, iou=0.839, dice=0.907]miou 0.8868855503051494
# f1_or_dsc 0.9400522995808847
# 100%|█████████| 60/60 [00:03<00:00, 18.76it/s, loss=1.57, iou=0.839, dice=0.907]
# loss 1.5337 - iou 0.8758 - val_loss 1.5722 - val_iou 0.8391
# best_iou 0.881358010410957
# best_dice 0.9359299219907856
# Epoch [59/300]
# 100%|██████████████████████| 18/18 [00:02<00:00,  8.48it/s, loss=1.5, iou=0.877]
#  98%|████████▊| 59/60 [00:00<00:00, 75.33it/s, loss=1.44, iou=0.865, dice=0.925]miou 0.8868855503051494
# f1_or_dsc 0.9400522995808847
# 100%|█████████| 60/60 [00:03<00:00, 19.05it/s, loss=1.44, iou=0.865, dice=0.925]
# loss 1.5001 - iou 0.8772 - val_loss 1.4400 - val_iou 0.8653
# best_iou 0.881358010410957
# best_dice 0.9359299219907856
# Epoch [60/300]
# 100%|██████████████████████| 18/18 [00:01<00:00,  9.07it/s, loss=1.4, iou=0.893]
#  98%|██████████▊| 59/60 [00:00<00:00, 74.77it/s, loss=1.4, iou=0.872, dice=0.93]miou 0.8868855503051494
# f1_or_dsc 0.9400522995808847
# 100%|███████████| 60/60 [00:03<00:00, 18.86it/s, loss=1.4, iou=0.872, dice=0.93]
# loss 1.4042 - iou 0.8931 - val_loss 1.4036 - val_iou 0.8720
# best_iou 0.881358010410957
# best_dice 0.9359299219907856
# Epoch [61/300]
# 100%|██████████████████████| 18/18 [00:01<00:00,  9.48it/s, loss=1.4, iou=0.893]
#  98%|████████▊| 59/60 [00:00<00:00, 78.47it/s, loss=1.63, iou=0.822, dice=0.897]miou 0.8868855503051494
# f1_or_dsc 0.9400522995808847
# 100%|█████████| 60/60 [00:03<00:00, 19.32it/s, loss=1.63, iou=0.822, dice=0.897]
# loss 1.4028 - iou 0.8925 - val_loss 1.6269 - val_iou 0.8223
# best_iou 0.881358010410957
# best_dice 0.9359299219907856
# Epoch [62/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.76it/s, loss=1.54, iou=0.861]
#  98%|████████▊| 59/60 [00:00<00:00, 81.81it/s, loss=1.41, iou=0.867, dice=0.926]miou 0.8868855503051494
# f1_or_dsc 0.9400522995808847
# 100%|█████████| 60/60 [00:03<00:00, 19.44it/s, loss=1.41, iou=0.867, dice=0.926]
# loss 1.5414 - iou 0.8609 - val_loss 1.4123 - val_iou 0.8666
# best_iou 0.881358010410957
# best_dice 0.9359299219907856
# Epoch [63/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.89it/s, loss=1.41, iou=0.879]
#  98%|████████▊| 59/60 [00:00<00:00, 77.79it/s, loss=1.32, iou=0.878, dice=0.934]miou 0.8868855503051494
# f1_or_dsc 0.9400522995808847
# 100%|█████████| 60/60 [00:03<00:00, 19.34it/s, loss=1.32, iou=0.878, dice=0.934]
# loss 1.4072 - iou 0.8793 - val_loss 1.3240 - val_iou 0.8776
# best_iou 0.881358010410957
# best_dice 0.9359299219907856
# Epoch [64/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.89it/s, loss=1.37, iou=0.888]
#  98%|█████████▊| 59/60 [00:00<00:00, 78.50it/s, loss=1.39, iou=0.872, dice=0.93]miou 0.8868855503051494
# f1_or_dsc 0.9400522995808847
# 100%|██████████| 60/60 [00:03<00:00, 19.36it/s, loss=1.39, iou=0.872, dice=0.93]
# loss 1.3690 - iou 0.8881 - val_loss 1.3904 - val_iou 0.8719
# best_iou 0.881358010410957
# best_dice 0.9359299219907856
# Epoch [65/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.87it/s, loss=1.32, iou=0.898]
#  98%|████████▊| 59/60 [00:00<00:00, 79.07it/s, loss=1.37, iou=0.868, dice=0.927]miou 0.8868855503051494
# f1_or_dsc 0.9400522995808847
# 100%|█████████| 60/60 [00:03<00:00, 19.69it/s, loss=1.37, iou=0.868, dice=0.927]
# loss 1.3168 - iou 0.8980 - val_loss 1.3681 - val_iou 0.8680
# best_iou 0.881358010410957
# best_dice 0.9359299219907856
# Epoch [66/300]
# 100%|█████████████████████| 18/18 [00:01<00:00,  9.24it/s, loss=1.37, iou=0.891]
#  98%|████████▊| 59/60 [00:00<00:00, 68.02it/s, loss=1.34, iou=0.866, dice=0.926]miou 0.8868855503051494
# f1_or_dsc 0.9400522995808847
# 100%|█████████| 60/60 [00:03<00:00, 18.73it/s, loss=1.34, iou=0.866, dice=0.926]
# loss 1.3689 - iou 0.8912 - val_loss 1.3433 - val_iou 0.8664
# best_iou 0.881358010410957
# best_dice 0.9359299219907856
# Epoch [67/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.78it/s, loss=1.27, iou=0.904]
#  98%|████████▊| 59/60 [00:00<00:00, 81.76it/s, loss=1.32, iou=0.868, dice=0.927]miou 0.8868855503051494
# f1_or_dsc 0.9400522995808847
# 100%|█████████| 60/60 [00:03<00:00, 19.65it/s, loss=1.32, iou=0.868, dice=0.927]
# loss 1.2689 - iou 0.9040 - val_loss 1.3179 - val_iou 0.8680
# best_iou 0.881358010410957
# best_dice 0.9359299219907856
# Epoch [68/300]
# 100%|██████████████████████| 18/18 [00:02<00:00,  8.85it/s, loss=1.3, iou=0.893]
#  98%|████████▊| 59/60 [00:00<00:00, 78.00it/s, loss=1.31, iou=0.881, dice=0.935]miou 0.890193566532121
# f1_or_dsc 0.9419073075836686
# 100%|█████████| 60/60 [00:03<00:00, 18.90it/s, loss=1.31, iou=0.881, dice=0.935]
# loss 1.3014 - iou 0.8931 - val_loss 1.3066 - val_iou 0.8808
# best_iou 0.881358010410957
# best_dice 0.9359299219907856
# Epoch [69/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.77it/s, loss=1.33, iou=0.893]
#  98%|████████▊| 59/60 [00:00<00:00, 78.31it/s, loss=1.27, iou=0.887, dice=0.939]miou 0.8933400495358624
# f1_or_dsc 0.9436657189550898
# 100%|█████████| 60/60 [00:03<00:00, 18.70it/s, loss=1.27, iou=0.887, dice=0.939]
# loss 1.3336 - iou 0.8928 - val_loss 1.2745 - val_iou 0.8873
# => saved best model
# best_iou 0.8872798721632275
# best_dice 0.9391165178170086
# Epoch [70/300]
# 100%|█████████████████████| 18/18 [00:01<00:00,  9.07it/s, loss=1.23, iou=0.907]
#  98%|████████▊| 59/60 [00:00<00:00, 79.02it/s, loss=1.27, iou=0.876, dice=0.933]miou 0.8933400495358624
# f1_or_dsc 0.9436657189550898
# 100%|█████████| 60/60 [00:03<00:00, 19.39it/s, loss=1.27, iou=0.876, dice=0.933]
# loss 1.2309 - iou 0.9070 - val_loss 1.2690 - val_iou 0.8764
# best_iou 0.8872798721632275
# best_dice 0.9391165178170086
# Epoch [71/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.94it/s, loss=1.25, iou=0.902]
#  98%|████████▊| 59/60 [00:00<00:00, 80.73it/s, loss=1.28, iou=0.874, dice=0.931]miou 0.8933400495358624
# f1_or_dsc 0.9436657189550898
# 100%|█████████| 60/60 [00:03<00:00, 19.45it/s, loss=1.28, iou=0.874, dice=0.931]
# loss 1.2528 - iou 0.9018 - val_loss 1.2839 - val_iou 0.8737
# best_iou 0.8872798721632275
# best_dice 0.9391165178170086
# Epoch [72/300]
# 100%|█████████████████████| 18/18 [00:01<00:00,  9.33it/s, loss=1.23, iou=0.903]
#  98%|█████████▊| 59/60 [00:00<00:00, 83.46it/s, loss=1.24, iou=0.888, dice=0.94]miou 0.894409129554861
# f1_or_dsc 0.9442618446048398
# 100%|██████████| 60/60 [00:03<00:00, 19.23it/s, loss=1.24, iou=0.888, dice=0.94]
# loss 1.2251 - iou 0.9032 - val_loss 1.2381 - val_iou 0.8878
# => saved best model
# best_iou 0.8877953999184833
# best_dice 0.9395343748765222
# Epoch [73/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.94it/s, loss=1.23, iou=0.901]
#  98%|████████▊| 59/60 [00:00<00:00, 81.30it/s, loss=1.25, iou=0.884, dice=0.937]miou 0.894409129554861
# f1_or_dsc 0.9442618446048398
# 100%|█████████| 60/60 [00:03<00:00, 19.32it/s, loss=1.25, iou=0.884, dice=0.937]
# loss 1.2261 - iou 0.9013 - val_loss 1.2494 - val_iou 0.8838
# best_iou 0.8877953999184833
# best_dice 0.9395343748765222
# Epoch [74/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.66it/s, loss=1.19, iou=0.907]
#  98%|█████████▊| 59/60 [00:00<00:00, 84.10it/s, loss=1.22, iou=0.89, dice=0.941]miou 0.899866319610315
# f1_or_dsc 0.9472943546837425
# 100%|██████████| 60/60 [00:03<00:00, 19.49it/s, loss=1.22, iou=0.89, dice=0.941]
# loss 1.1907 - iou 0.9068 - val_loss 1.2224 - val_iou 0.8900
# => saved best model
# best_iou 0.890011259654318
# best_dice 0.940717424883859
# Epoch [75/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.55it/s, loss=1.18, iou=0.912]
#  98%|█████████▊| 59/60 [00:01<00:00, 75.17it/s, loss=1.21, iou=0.89, dice=0.941]miou 0.899866319610315
# f1_or_dsc 0.9472943546837425
# 100%|██████████| 60/60 [00:03<00:00, 18.66it/s, loss=1.21, iou=0.89, dice=0.941]
# loss 1.1810 - iou 0.9124 - val_loss 1.2106 - val_iou 0.8901
# => saved best model
# best_iou 0.8901302426833235
# best_dice 0.9409037396377808
# Epoch [76/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  9.00it/s, loss=1.16, iou=0.914]
# 100%|█████████| 60/60 [00:00<00:00, 81.54it/s, loss=1.19, iou=0.894, dice=0.943]miou 0.9019854783481407
# f1_or_dsc 0.9484672607821464
# 100%|█████████| 60/60 [00:03<00:00, 19.11it/s, loss=1.19, iou=0.894, dice=0.943]
# loss 1.1606 - iou 0.9137 - val_loss 1.1917 - val_iou 0.8938
# => saved best model
# best_iou 0.8938471939792328
# best_dice 0.9429882631657708
# Epoch [77/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.99it/s, loss=1.16, iou=0.913]
#  98%|████████▊| 59/60 [00:00<00:00, 80.92it/s, loss=1.23, iou=0.884, dice=0.937]miou 0.9019854783481407
# f1_or_dsc 0.9484672607821464
# 100%|█████████| 60/60 [00:03<00:00, 19.34it/s, loss=1.23, iou=0.884, dice=0.937]
# loss 1.1554 - iou 0.9126 - val_loss 1.2326 - val_iou 0.8842
# best_iou 0.8938471939792328
# best_dice 0.9429882631657708
# Epoch [78/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.86it/s, loss=1.19, iou=0.906]
# 100%|██████████| 60/60 [00:00<00:00, 79.82it/s, loss=1.22, iou=0.88, dice=0.935]miou 0.9019854783481407
# f1_or_dsc 0.9484672607821464
# 100%|██████████| 60/60 [00:03<00:00, 18.97it/s, loss=1.22, iou=0.88, dice=0.935]
# loss 1.1943 - iou 0.9057 - val_loss 1.2213 - val_iou 0.8799
# best_iou 0.8938471939792328
# best_dice 0.9429882631657708
# Epoch [79/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.72it/s, loss=1.15, iou=0.912]
#  98%|██████████▊| 59/60 [00:00<00:00, 75.32it/s, loss=1.2, iou=0.888, dice=0.94]miou 0.9019854783481407
# f1_or_dsc 0.9484672607821464
# 100%|███████████| 60/60 [00:03<00:00, 18.81it/s, loss=1.2, iou=0.888, dice=0.94]
# loss 1.1472 - iou 0.9123 - val_loss 1.2015 - val_iou 0.8882
# best_iou 0.8938471939792328
# best_dice 0.9429882631657708
# Epoch [80/300]
# 100%|█████████████████████| 18/18 [00:01<00:00,  9.07it/s, loss=1.12, iou=0.921]
#  98%|█████████▊| 59/60 [00:00<00:00, 71.41it/s, loss=1.23, iou=0.88, dice=0.935]miou 0.9019854783481407
# f1_or_dsc 0.9484672607821464
# 100%|██████████| 60/60 [00:03<00:00, 18.86it/s, loss=1.23, iou=0.88, dice=0.935]
# loss 1.1194 - iou 0.9206 - val_loss 1.2273 - val_iou 0.8798
# best_iou 0.8938471939792328
# best_dice 0.9429882631657708
# Epoch [81/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.90it/s, loss=1.13, iou=0.915]
#  98%|████████▊| 59/60 [00:00<00:00, 81.36it/s, loss=1.21, iou=0.885, dice=0.938]miou 0.9019854783481407
# f1_or_dsc 0.9484672607821464
# 100%|█████████| 60/60 [00:03<00:00, 19.37it/s, loss=1.21, iou=0.885, dice=0.938]
# loss 1.1256 - iou 0.9154 - val_loss 1.2057 - val_iou 0.8849
# best_iou 0.8938471939792328
# best_dice 0.9429882631657708
# Epoch [82/300]
# 100%|█████████████████████| 18/18 [00:01<00:00,  9.08it/s, loss=1.13, iou=0.916]
#  98%|█████████▊| 59/60 [00:00<00:00, 78.98it/s, loss=1.19, iou=0.888, dice=0.94]miou 0.9019854783481407
# f1_or_dsc 0.9484672607821464
# 100%|██████████| 60/60 [00:03<00:00, 19.39it/s, loss=1.19, iou=0.888, dice=0.94]
# loss 1.1307 - iou 0.9159 - val_loss 1.1946 - val_iou 0.8883
# best_iou 0.8938471939792328
# best_dice 0.9429882631657708
# Epoch [83/300]
# 100%|██████████████████████| 18/18 [00:02<00:00,  8.38it/s, loss=1.11, iou=0.92]
#  98%|████████▊| 59/60 [00:00<00:00, 76.94it/s, loss=1.22, iou=0.882, dice=0.936]miou 0.9019854783481407
# f1_or_dsc 0.9484672607821464
# 100%|█████████| 60/60 [00:03<00:00, 19.27it/s, loss=1.22, iou=0.882, dice=0.936]
# loss 1.1110 - iou 0.9197 - val_loss 1.2213 - val_iou 0.8817
# best_iou 0.8938471939792328
# best_dice 0.9429882631657708
# Epoch [84/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.27it/s, loss=1.12, iou=0.915]
#  98%|████████▊| 59/60 [00:00<00:00, 77.14it/s, loss=1.22, iou=0.883, dice=0.937]miou 0.9019854783481407
# f1_or_dsc 0.9484672607821464
# 100%|█████████| 60/60 [00:03<00:00, 19.01it/s, loss=1.22, iou=0.883, dice=0.937]
# loss 1.1162 - iou 0.9153 - val_loss 1.2174 - val_iou 0.8834
# best_iou 0.8938471939792328
# best_dice 0.9429882631657708
# Epoch [85/300]
# 100%|██████████████████████| 18/18 [00:02<00:00,  8.94it/s, loss=1.1, iou=0.923]
#  98%|█████████▊| 59/60 [00:00<00:00, 74.70it/s, loss=1.2, iou=0.887, dice=0.939]miou 0.9019854783481407
# f1_or_dsc 0.9484672607821464
# 100%|██████████| 60/60 [00:03<00:00, 19.00it/s, loss=1.2, iou=0.887, dice=0.939]
# loss 1.1018 - iou 0.9227 - val_loss 1.1992 - val_iou 0.8867
# best_iou 0.8938471939792328
# best_dice 0.9429882631657708
# Epoch [86/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.73it/s, loss=1.09, iou=0.923]
#  98%|████████▊| 59/60 [00:00<00:00, 79.49it/s, loss=1.21, iou=0.883, dice=0.937]miou 0.9019854783481407
# f1_or_dsc 0.9484672607821464
# 100%|█████████| 60/60 [00:03<00:00, 19.05it/s, loss=1.21, iou=0.883, dice=0.937]
# loss 1.0920 - iou 0.9229 - val_loss 1.2115 - val_iou 0.8834
# best_iou 0.8938471939792328
# best_dice 0.9429882631657708
# Epoch [87/300]
# ...
# 100%|████████| 60/60 [00:03<00:00, 19.56it/s, loss=0.859, iou=0.893, dice=0.942]
# loss 0.6793 - iou 0.9339 - val_loss 0.8593 - val_iou 0.8932
# best_iou 0.898212846220991
# best_dice 0.9454081278970837
# Epoch [263/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.68it/s, loss=0.68, iou=0.935]
#  98%|███████▊| 59/60 [00:00<00:00, 78.26it/s, loss=0.858, iou=0.893, dice=0.942]miou 0.9071726729739203
# f1_or_dsc 0.9513272561307567
# 100%|████████| 60/60 [00:03<00:00, 19.33it/s, loss=0.858, iou=0.893, dice=0.942]
# loss 0.6801 - iou 0.9346 - val_loss 0.8585 - val_iou 0.8933
# best_iou 0.898212846220991
# best_dice 0.9454081278970837
# Epoch [264/300]
# 100%|████████████████████| 18/18 [00:02<00:00,  8.87it/s, loss=0.662, iou=0.936]
#  98%|████████▊| 59/60 [00:01<00:00, 71.40it/s, loss=0.86, iou=0.893, dice=0.942]miou 0.9071726729739203
# f1_or_dsc 0.9513272561307567
# 100%|█████████| 60/60 [00:03<00:00, 18.40it/s, loss=0.86, iou=0.893, dice=0.942]
# loss 0.6620 - iou 0.9358 - val_loss 0.8600 - val_iou 0.8930
# best_iou 0.898212846220991
# best_dice 0.9454081278970837
# Epoch [265/300]
# 100%|████████████████████| 18/18 [00:02<00:00,  8.91it/s, loss=0.651, iou=0.937]
#  98%|███████▊| 59/60 [00:00<00:00, 80.78it/s, loss=0.854, iou=0.894, dice=0.943]miou 0.9071726729739203
# f1_or_dsc 0.9513272561307567
# 100%|████████| 60/60 [00:03<00:00, 19.21it/s, loss=0.854, iou=0.894, dice=0.943]
# loss 0.6508 - iou 0.9369 - val_loss 0.8537 - val_iou 0.8939
# best_iou 0.898212846220991
# best_dice 0.9454081278970837
# Epoch [266/300]
# 100%|████████████████████| 18/18 [00:02<00:00,  8.92it/s, loss=0.663, iou=0.936]
#  98%|███████▊| 59/60 [00:00<00:00, 76.75it/s, loss=0.854, iou=0.894, dice=0.943]miou 0.9071726729739203
# f1_or_dsc 0.9513272561307567
# 100%|████████| 60/60 [00:03<00:00, 19.02it/s, loss=0.854, iou=0.894, dice=0.943]
# loss 0.6628 - iou 0.9361 - val_loss 0.8541 - val_iou 0.8939
# best_iou 0.898212846220991
# best_dice 0.9454081278970837
# Epoch [267/300]
# 100%|██████████████████████| 18/18 [00:01<00:00,  9.08it/s, loss=0.64, iou=0.94]
# 100%|████████| 60/60 [00:00<00:00, 81.13it/s, loss=0.855, iou=0.894, dice=0.943]miou 0.9071726729739203
# f1_or_dsc 0.9513272561307567
# 100%|████████| 60/60 [00:03<00:00,
miou 0.9071726729739203
# f1_or_dsc 0.9513272561307567
# 100%|████████| 60/60 [00:03<00:00, 19.07it/s, loss=0.853, iou=0.892, dice=0.942]
# loss 0.7456 - iou 0.9224 - val_loss 0.8526 - val_iou 0.8918
# best_iou 0.898212846220991
# best_dice 0.9454081278970837
# Epoch [298/300]
# 100%|████████████████████| 18/18 [00:02<00:00,  8.71it/s, loss=0.714, iou=0.926]
#  98%|████████▊| 59/60 [00:00<00:00, 77.14it/s, loss=0.88, iou=0.888, dice=0.939]miou 0.9071726729739203
# f1_or_dsc 0.9513272561307567
# 100%|█████████| 60/60 [00:03<00:00, 19.22it/s, loss=0.88, iou=0.888, dice=0.939]
# loss 0.7140 - iou 0.9262 - val_loss 0.8803 - val_iou 0.8881
# best_iou 0.898212846220991
# best_dice 0.9454081278970837
# Epoch [299/300]
# 100%|█████████████████████| 18/18 [00:02<00:00,  8.76it/s, loss=0.739, iou=0.92]
#  98%|███████▊| 59/60 [00:00<00:00, 78.19it/s, loss=0.988, iou=0.874, dice=0.931]miou 0.9071726729739203
# f1_or_dsc 0.9513272561307567
# 100%|████████| 60/60 [00:03<00:00, 19.25it/s, loss=0.988, iou=0.874, dice=0.931]
# loss 0.7385 - iou 0.9203 - val_loss 0.9877 - val_iou 0.8743
# best_iou 0.898212846220991
# best_dice 0.9454081278970837

# %%
# !python val.py --name ph2_nb_testing_batch_8
# Out:
# {'name': 'ph2_nb_testing_batch_8', 'dataset': 'isic', 'img_ext': '.png', 'mask_ext': '.png', 'input_channels': 3, 'num_classes': 1, 'input_w': 256, 'input_h': 256, 'arch': 'transfuse', 'batch_size': 1, 'path': 'no', 'cfg': None, 'opts': None, 'num_workers': 4, 'zip': False, 'cache_mode': 'part', 'resume': None, 'accumulation_steps': None, 'use_checkpoint': False, 'amp_opt_level': 'O1', 'tag': None, 'eval': False, 'throughput': False}
# --------------------
# accumulation_steps: None
# amp_opt_level: O1
# arch: UCM_Net
# batch_size: 8
# cache_mode: part
# cfg: None
# dataset: ../ph2/
# deep_supervision: False
# early_stopping: -1
# epochs: 300
# eval: False
# factor: 0.1
# gamma: 0.6666666666666666
# img_ext: .bmp
# input_channels: 3
# input_h: 256
# input_w: 256
# loss: GT_BceDiceLoss_new1
# lr: 0.001
# mask_ext: _lesion.bmp
# milestones: 1,2
# min_lr: 1e-05
# momentum: 0.9
# name: ph2_nb_testing_batch_8
# nesterov: False
# nrand: 44
# num_classes: 1
# num_workers: 4
# optimizer: AdamW
# opts: None
# patience: 2
# resume: None
# scheduler: CosineAnnealingLR
# tag: None
# throughput: False
# use_checkpoint: False
# weight_decay: 0.01
# zip: False
# --------------------
# => creating model UCM_Net
# torch.Size([1, 3, 256, 256]) False transfuse
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv2d'>.
# [INFO] Register count_normalization() for <class 'torch.nn.modules.normalization.LayerNorm'>.
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.dropout.Dropout'>.
# GigaFLOPs: 0.045193216
# 47436
# 100%|███████████████████████████████████████████| 60/60 [00:00<00:00, 66.44it/s]
# IoU: 0.89821285
# Dice: 0.94540813
# 100%|███████████████████████████████████████████| 60/60 [00:00<00:00, 68.18it/s]
# miou* 0.9071726729739203
# f1_or_dsc* 0.9513272561307567
# 100%|███████████████████████████████████████████| 60/60 [00:00<00:00, 70.58it/s]
# FPS: 70.5219
#   0%|                                                     | 0/1 [00:00<?, ?it/s]
# Estimated total memory usage during inference: 1.1810 MB
